# %%
import pandas as pd
import os
import json
import csv
import re, datetime
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, timedelta

from global_functions import *

# %% [markdown]
# ### Information
#
# Input files:
# data_processing/bugs_info.csv
# raw_data/bug_history.csv
#
# Output files:
# data_processing/bugs_info.csv (TO COMPLETE)
# data_processing/bug_history.csv
# data/assigned_to_ids.csv

# %%
bugs_processing_file = '.'+os.sep+'data_processing'+os.sep+'bugs_info.zip'

bug_history_orig = './raw_data/bug_history.zip'
processed_history_file = './data_processing/bug_history.zip'

injected_assignments_file =  './data/assigned_to_ids.zip'

# %%
#Load data
#use os.sep to get the separator based on the operating system so as not to have issues running the script in other operating systems
df_info = pd.read_csv(bugs_processing_file,index_col=False)
df_info['creation_time'] = pd.to_datetime(df_info['creation_time'])
df_info.head(n=2)
# Out:
#        id  release   Product       creation_time version resolution  \
# 0  475361      4.5  Platform 2015-08-19 10:50:25     4.5      FIXED
# 1  475365      4.6  Platform 2015-08-19 11:34:37     4.6      FIXED
#
#    is_assigned  is_resolved  is_fixed first_assignment_date  \
# 0            0            1         1                   NaN
# 1            0            1         1                   NaN
#
#   last_assignment_date   first_resolved_date    last_resolved_date  \
# 0                  NaN  2015-08-19T11:53:03Z  2015-08-19T11:53:03Z
# 1                  NaN  2015-08-26T14:29:30Z  2015-08-26T14:29:30Z
#
#        first_fixed_date       last_fixed_date
# 0  2015-08-19T11:53:03Z  2015-08-19T11:53:03Z
# 1  2015-08-26T14:29:30Z  2015-08-26T14:29:30Z

# %%
len(df_info)
# Out:
# 141010

# %%
#filter out the history of the bugs we excluded
bug_history = pd.read_csv(bug_history_orig,index_col=False)
bug_history = bug_history[bug_history['id'].isin(df_info.id.unique().tolist())]
bug_history.to_csv(processed_history_file,index=False)

# %%
df_bugs = df_info[['id','release','Product','creation_time','version','resolution']].drop_duplicates()

df = bug_history.copy()

#Bugs that were assigned
assigned_bugs = df[(df['what']=='status') & (df['added']=='ASSIGNED')].id.unique().tolist()
#Bugs that were resolved
resolved_bugs = df[(df['what']=='status') & (df['added']=='RESOLVED')].id.unique().tolist()
#Bugs that were fixed
fixed_bugs = df[(df['what']=='resolution') & (df['added']=='FIXED')].id.unique().tolist()


df_bugs['is_assigned'] = 0
df_bugs.loc[df_bugs['id'].isin(assigned_bugs),'is_assigned'] = 1

df_bugs['is_resolved'] = 0
df_bugs.loc[df_bugs['id'].isin(resolved_bugs),'is_resolved'] = 1

df_bugs['is_fixed'] = 0
df_bugs.loc[df_bugs['id'].isin(fixed_bugs),'is_fixed'] = 1

df_bugs.head(n=2)

min_assingment_date = (
    df[(df['id'].isin(assigned_bugs)) & 
       (df['what']=='status') & 
       (df['added']=='ASSIGNED')]
    .groupby('id')
    ['when']
    .min()
    .reset_index()
    .rename(index=str,columns={'when':'first_assignment_date'})
)

df_bugs = pd.merge(df_bugs,min_assingment_date,on=['id'],how='outer')

max_assingment_date = (
    df[(df['id'].isin(assigned_bugs)) & 
       (df['what']=='status') & 
       (df['added']=='ASSIGNED')]
    .groupby('id')
    ['when']
    .max()
    .reset_index()
    .rename(index=str,columns={'when':'last_assignment_date'})
)

df_bugs = pd.merge(df_bugs,max_assingment_date,on=['id'],how='outer')


min_resolved_date = (
    df[(df['id'].isin(resolved_bugs)) & 
      (df['what']=='status') & 
       (df['added']=='RESOLVED')]
    .groupby('id')
    ['when']
    .min()
    .reset_index()
    .rename(index=str,columns={'when':'first_resolved_date'})
)
df_bugs = pd.merge(df_bugs,min_resolved_date,on=['id'],how='outer')

max_resolved_date = (
    df[(df['id'].isin(resolved_bugs)) & 
      (df['what']=='status') & 
       (df['added']=='RESOLVED')]
    .groupby('id')
    ['when']
    .max()
    .reset_index()
    .rename(index=str,columns={'when':'last_resolved_date'})
)
df_bugs = pd.merge(df_bugs,max_resolved_date,on=['id'],how='outer')

min_fixed_date = (
    df[(df['id'].isin(fixed_bugs)) & 
      (df['what']=='resolution') & 
       (df['added']=='FIXED')]
    .groupby('id')
    ['when']
    .min()
    .reset_index()
    .rename(index=str,columns={'when':'first_fixed_date'})
)
df_bugs = pd.merge(df_bugs,min_fixed_date,on=['id'],how='outer')

max_fixed_date = (
    df[(df['id'].isin(fixed_bugs)) & 
      (df['what']=='resolution') & 
       (df['added']=='FIXED')]
    .groupby('id')
    ['when']
    .max()
    .reset_index()
    .rename(index=str,columns={'when':'last_fixed_date'})
)
df_bugs = pd.merge(df_bugs,max_fixed_date,on=['id'],how='outer')

df_bugs = df_bugs.fillna('')
df_bugs.head()
# Out:
#        id  release   Product       creation_time version resolution  \
# 0  475361      4.5  Platform 2015-08-19 10:50:25     4.5      FIXED
# 1  475365      4.6  Platform 2015-08-19 11:34:37     4.6      FIXED
# 2  475370      4.5  Platform 2015-08-19 12:09:06     4.5  DUPLICATE
# 3  475379      4.5  Platform 2015-08-19 13:39:12     4.5
# 4  475407      4.5  Platform 2015-08-19 17:06:10     4.5      FIXED
#
#    is_assigned  is_resolved  is_fixed first_assignment_date  \
# 0            0            1         1
# 1            0            1         1
# 2            0            0         0
# 3            0            0         0
# 4            0            1         1
#
#   last_assignment_date   first_resolved_date    last_resolved_date  \
# 0                       2015-08-19T11:53:03Z  2015-08-19T11:53:03Z
# 1                       2015-08-26T14:29:30Z  2015-08-26T14:29:30Z
# 2
# 3
# 4                       2015-08-19T17:15:25Z  2015-08-19T17:15:25Z
#
#        first_fixed_date       last_fixed_date
# 0  2015-08-19T11:53:03Z  2015-08-19T11:53:03Z
# 1  2015-08-26T14:29:30Z  2015-08-26T14:29:30Z
# 2
# 3
# 4  2015-08-19T17:15:25Z  2015-08-19T17:15:25Z

# %%
df_bugs.to_csv(bugs_processing_file,index=False)

# %% [markdown]
# ### Assignment fixes
#
# In eclipse bug handling, there  are 2 ways that bugs are assigned aside the ASSIGNED status:
# 1. The bug is assigned to an email address component_name-triaged@eclipse.org
# 2. The person who is assigned to the bug also resolves it
#
# In these 2 cases, we inject ASSIGNED statuses so that we minimize the threat to validity

# %% [markdown]
# #### CASE 1: -triaged@eclipse.org

# %%
injected_assignments = pd.DataFrame()

# %%
#bugs that are assigned by the status ASSIGNED
bugs_assigned = df_bugs[df_bugs['is_assigned']==1].id.unique().tolist()

triaged_with_email = bug_history[(bug_history['added'].str.find('-triaged@eclipse.org')>=0)]
triaged_with_email_bugs = [x for x in triaged_with_email.id.unique().tolist() if x not in bugs_assigned]
len(triaged_with_email_bugs)
# Out:
# 5174

# %%
#inject in the history the assignment row
to_inject = triaged_with_email.copy()
to_inject['removed'] = ''
to_inject['who'] = to_inject['added']
to_inject['added'] = 'ASSIGNED'
to_inject['what'] = 'status'

injected_assignments = injected_assignments.append(to_inject,ignore_index=True)

bug_history = bug_history.append(to_inject,ignore_index=True)

df_bugs.loc[df_bugs['id'].isin(to_inject.id.unique().tolist()),'is_assigned'] = 1

# %% [markdown]
# #### CASE 2: assinged by email also resolves it

# %%
bugs_assigned = df_bugs[df_bugs['is_assigned']==1].id.unique().tolist()
len(bugs_assigned)
# Out:
# 52970

# %%
history_investigate = bug_history[~bug_history['id'].isin(bugs_assigned)]
history_investigate.head()
# Out:
#                         added      id                         removed  \
# 9      david_audel@fr.ibm.com  100002      jdt-core-inbox@eclipse.org
# 10                   RESOLVED  100004                             NEW
# 11                  DUPLICATE  100004                             NaN
# 43  susan_franklin@us.ibm.com  100014  platform-doc-inbox@eclipse.org
# 44                   RESOLVED  100014                             NEW
#
#            what                  when                         who
# 9   assigned_to  2006-10-06T19:42:16Z  Olivier_Thomann@ca.ibm.com
# 10       status  2005-06-14T16:32:08Z     dirk_baeumer@ch.ibm.com
# 11   resolution  2005-06-14T16:32:08Z     dirk_baeumer@ch.ibm.com
# 43  assigned_to  2005-06-23T11:46:04Z      Tod_Creasey@ca.ibm.com
# 44       status  2005-06-23T14:36:36Z          susan@rapicorp.com

# %%
#Do the assignment fixes
len(history_investigate[history_investigate['what']=='assigned_to'])
# Out:
# 56573

# %%
#bugs that have the assigned_to field
assigned_to=history_investigate[history_investigate['what']=='assigned_to'].id.unique()

# %%
assigned_to_bugs=df_bugs[df_bugs['id'].isin(assigned_to)]
assigned_resolved=assigned_to_bugs[assigned_to_bugs['is_resolved']>0]
print('# resolved',len(assigned_resolved.id.unique()))
print('# non resolved',len(assigned_to_bugs[assigned_to_bugs['is_resolved']==0]))
# Out:
# # resolved 34341
# # non resolved 8126

# %%
y=history_investigate[history_investigate['id'].isin(assigned_to)]
y.head()
# Out:
#                         added      id                         removed  \
# 9      david_audel@fr.ibm.com  100002      jdt-core-inbox@eclipse.org
# 43  susan_franklin@us.ibm.com  100014  platform-doc-inbox@eclipse.org
# 44                   RESOLVED  100014                             NEW
# 45                      FIXED  100014                             NaN
# 46                    3.1 RC4  100014                             ---
#
#                 what                  when                         who
# 9        assigned_to  2006-10-06T19:42:16Z  Olivier_Thomann@ca.ibm.com
# 43       assigned_to  2005-06-23T11:46:04Z      Tod_Creasey@ca.ibm.com
# 44            status  2005-06-23T14:36:36Z          susan@rapicorp.com
# 45        resolution  2005-06-23T14:36:36Z          susan@rapicorp.com
# 46  target_milestone  2005-06-23T14:36:36Z          susan@rapicorp.com

# %%
#only work with the ones that actually got resolved
y = y[y['id'].isin(assigned_resolved.id.unique().tolist())]
y.head()
# Out:
#                         added      id                         removed  \
# 43  susan_franklin@us.ibm.com  100014  platform-doc-inbox@eclipse.org
# 44                   RESOLVED  100014                             NEW
# 45                      FIXED  100014                             NaN
# 46                    3.1 RC4  100014                             ---
# 47                   VERIFIED  100014                        RESOLVED
#
#                 what                  when                     who
# 43       assigned_to  2005-06-23T11:46:04Z  Tod_Creasey@ca.ibm.com
# 44            status  2005-06-23T14:36:36Z      susan@rapicorp.com
# 45        resolution  2005-06-23T14:36:36Z      susan@rapicorp.com
# 46  target_milestone  2005-06-23T14:36:36Z      susan@rapicorp.com
# 47            status  2005-06-24T02:33:53Z      susan@rapicorp.com

# %%
#find who was assigned to them and who resolved them

# %%
resolutions = y[(y['added']=='RESOLVED') & (y['what']=='status')]
resolutions.head()
# Out:
#         added      id removed    what                  when  \
# 44   RESOLVED  100014     NEW  status  2005-06-23T14:36:36Z
# 69   RESOLVED  100017     NEW  status  2005-11-18T21:19:32Z
# 94   RESOLVED  100025     NEW  status  2011-04-25T22:03:02Z
# 100  RESOLVED  100030     NEW  status  2005-12-07T23:08:28Z
# 147  RESOLVED  100040     NEW  status  2005-06-15T15:41:25Z
#
#                           who
# 44         susan@rapicorp.com
# 69    john.arthorne@gmail.com
# 94           cgold@us.ibm.com
# 100       bokowski@google.com
# 147  eclipse.felipe@gmail.com

# %%
resolutions=resolutions[['id','who']]
resolutions.head()
# Out:
#          id                       who
# 44   100014        susan@rapicorp.com
# 69   100017   john.arthorne@gmail.com
# 94   100025          cgold@us.ibm.com
# 100  100030       bokowski@google.com
# 147  100040  eclipse.felipe@gmail.com

# %%
len(resolutions.id.unique())
# Out:
# 34341

# %%
assignments = y[(y['what']=='assigned_to')]
assignments.head(n=10)
# Out:
#                                     added      id  \
# 43              susan_franklin@us.ibm.com  100014
# 66   platform-resources-inbox@eclipse.org  100017
# 87                       dejan@ca.ibm.com  100025
# 89                      deboer@ca.ibm.com  100025
# 92          platform-ua-inbox@eclipse.org  100025
# 99                    bokowski@ca.ibm.com  100030
# 146            felipe_heidrich@ca.ibm.com  100040
# 225        platform-doc-inbox@eclipse.org  100066
# 271            veronika_irvine@ca.ibm.com  100083
# 343        platform-ant-inbox@eclipse.org  100101
#
#                              removed         what                  when  \
# 43    platform-doc-inbox@eclipse.org  assigned_to  2005-06-23T11:46:04Z
# 66        jdt-core-inbox@eclipse.org  assigned_to  2005-06-16T11:16:32Z
# 87     Platform-UI-Inbox@eclipse.org  assigned_to  2005-06-14T17:38:37Z
# 89                  dejan@ca.ibm.com  assigned_to  2005-06-14T18:07:12Z
# 92                 deboer@ca.ibm.com  assigned_to  2009-04-15T14:37:25Z
# 99     Platform-UI-Inbox@eclipse.org  assigned_to  2005-06-14T18:41:44Z
# 146   platform-swt-inbox@eclipse.org  assigned_to  2005-06-14T19:24:25Z
# 225  platform-help-inbox@eclipse.org  assigned_to  2005-06-14T20:18:14Z
# 271   platform-swt-inbox@eclipse.org  assigned_to  2005-06-15T18:29:23Z
# 343       jdt-core-inbox@eclipse.org  assigned_to  2005-06-14T23:04:54Z
#
#                             who
# 43       Tod_Creasey@ca.ibm.com
# 66   jerome_lanneluc@fr.ibm.com
# 87        eclipse@pookzilla.net
# 89             dejan@ca.ibm.com
# 92             cgold@us.ibm.com
# 99        eclipse@pookzilla.net
# 146    eclipse.felipe@gmail.com
# 225   sonia_dimitrov@ca.ibm.com
# 271         snorthov@ca.ibm.com
# 343   philippe_mulet@fr.ibm.com

# %%
assignments = assignments[['id','added']].rename(index=str,columns={'added':'who'})
assignments.head()
# Out:
#         id                                   who
# 43  100014             susan_franklin@us.ibm.com
# 66  100017  platform-resources-inbox@eclipse.org
# 87  100025                      dejan@ca.ibm.com
# 89  100025                     deboer@ca.ibm.com
# 92  100025         platform-ua-inbox@eclipse.org

# %%
len(assignments.id.unique())
# Out:
# 34341

# %%
merged_assign_res_bugs = pd.merge(resolutions,assignments,on=['id','who'],how='inner')
merged_assign_res_bugs
# Out:
#          id                            who
# 0    239496      rafael.oliveira@gmail.com
# 1    241551     jerome_lanneluc@fr.ibm.com
# 2    244176              francisu@ieee.org
# 3    246493            gheorghe@ca.ibm.com
# 4    247541          canada.eric@gmail.com
# 5    254343            pwebster@ca.ibm.com
# 6    254495         grant_gayed@ca.ibm.com
# 7    254496         grant_gayed@ca.ibm.com
# 8    254497      Silenio_Quarti@ca.ibm.com
# 9    254813       Kevin_McGuire@ca.ibm.com
# 10   258016            emoffatt@ca.ibm.com
# 11   258672         grant_gayed@ca.ibm.com
# 12   258675            gheorghe@ca.ibm.com
# 13   260892    tom.schindl@bestsolution.at
# 14   260904            emoffatt@ca.ibm.com
# 15   262982      Silenio_Quarti@ca.ibm.com
# 16   265953            emoffatt@ca.ibm.com
# 17   267613            gheorghe@ca.ibm.com
# 18   269269            emoffatt@ca.ibm.com
# 19   269269            emoffatt@ca.ibm.com
# 20   270768      Michael_Rennie@ca.ibm.com
# 21   270954      Silenio_Quarti@ca.ibm.com
# 22   281440      Silenio_Quarti@ca.ibm.com
# 23   284106            gheorghe@ca.ibm.com
# 24   287307            gheorghe@ca.ibm.com
# 25   287307            gheorghe@ca.ibm.com
# 26   293260     krzysztof.daniel@gmail.com
# 27   294053      Silenio_Quarti@ca.ibm.com
# 28   295483      Silenio_Quarti@ca.ibm.com
# 29   295794      Silenio_Quarti@ca.ibm.com
# ..      ...                            ...
# 220  432632            tjwatson@us.ibm.com
# 221  432894            tjwatson@us.ibm.com
# 222  433023            tjwatson@us.ibm.com
# 223  434605  pascal.rapicault@ericsson.com
# 224  434662  pascal.rapicault@ericsson.com
# 225  435407       Vikas.Chandra@in.ibm.com
# 226  435407       Vikas.Chandra@in.ibm.com
# 227  436073            tjwatson@us.ibm.com
# 228  436082            tjwatson@us.ibm.com
# 229  436485  arunkumar.thondapu@in.ibm.com
# 230  436698            tjwatson@us.ibm.com
# 231  441098            pascal@rapicorp.com
# 232  441848            tjwatson@us.ibm.com
# 233  442641            tjwatson@us.ibm.com
# 234  443527  arunkumar.thondapu@in.ibm.com
# 235  445660            tjwatson@us.ibm.com
# 236  449990  arunkumar.thondapu@in.ibm.com
# 237  449990  arunkumar.thondapu@in.ibm.com
# 238  454911            tjwatson@us.ibm.com
# 239  460633            tjwatson@us.ibm.com
# 240  460637            tjwatson@us.ibm.com
# 241  466755            tjwatson@us.ibm.com
# 242  475760            tjwatson@us.ibm.com
# 243  483665            tjwatson@us.ibm.com
# 244  483665            tjwatson@us.ibm.com
# 245  485692            tjwatson@us.ibm.com
# 246  509648         Lars.Vogel@vogella.com
# 247  515303        sarika.sinha@in.ibm.com
# 248  526655                loskutov@gmx.de
# 249  526663                loskutov@gmx.de
#
# [250 rows x 2 columns]

# %%
len(merged_assign_res_bugs.id.unique())
# Out:
# 230

# %%
#inject the assignment for the 230 cases where the person who got assinged the bug, also resolved it

# %%
assigned_injections = y[(y['what']=='assigned_to')]
assigned_injections = assigned_injections[assigned_injections['id'].isin(merged_assign_res_bugs.id.unique())]

#inject in the history the assignment row
assigned_injections['removed'] = ''
assigned_injections['who'] = assigned_injections['added']
assigned_injections['what'] = 'status'
assigned_injections['added'] = 'ASSIGNED'

injected_assignments = injected_assignments.append(assigned_injections,ignore_index=True)

bug_history = bug_history.append(assigned_injections,ignore_index=True)

df_bugs.loc[df_bugs['id'].isin(assigned_injections.id.unique().tolist()),'is_assigned'] = 1

# %%
injected_assignments.to_csv(injected_assignments_file,index=False)

# %%
#Re-run the info analysis after the injection
df_bugs = df_info[['id','release','Product','creation_time','version','resolution']].drop_duplicates()

df = bug_history.copy()

#Bugs that were assigned
assigned_bugs = df[(df['what']=='status') & (df['added']=='ASSIGNED')].id.unique().tolist()
#Bugs that were resolved
resolved_bugs = df[(df['what']=='status') & (df['added']=='RESOLVED')].id.unique().tolist()
#Bugs that were fixed
fixed_bugs = df[(df['what']=='resolution') & (df['added']=='FIXED')].id.unique().tolist()


df_bugs['is_assigned'] = 0
df_bugs.loc[df_bugs['id'].isin(assigned_bugs),'is_assigned'] = 1

df_bugs['is_resolved'] = 0
df_bugs.loc[df_bugs['id'].isin(resolved_bugs),'is_resolved'] = 1

df_bugs['is_fixed'] = 0
df_bugs.loc[df_bugs['id'].isin(fixed_bugs),'is_fixed'] = 1

df_bugs.head(n=2)

min_assingment_date = (
    df[(df['id'].isin(assigned_bugs)) & 
       (df['what']=='status') & 
       (df['added']=='ASSIGNED')]
    .groupby('id')
    ['when']
    .min()
    .reset_index()
    .rename(index=str,columns={'when':'first_assignment_date'})
)

df_bugs = pd.merge(df_bugs,min_assingment_date,on=['id'],how='outer')

max_assingment_date = (
    df[(df['id'].isin(assigned_bugs)) & 
       (df['what']=='status') & 
       (df['added']=='ASSIGNED')]
    .groupby('id')
    ['when']
    .max()
    .reset_index()
    .rename(index=str,columns={'when':'last_assignment_date'})
)

df_bugs = pd.merge(df_bugs,max_assingment_date,on=['id'],how='outer')


min_resolved_date = (
    df[(df['id'].isin(resolved_bugs)) & 
      (df['what']=='status') & 
       (df['added']=='RESOLVED')]
    .groupby('id')
    ['when']
    .min()
    .reset_index()
    .rename(index=str,columns={'when':'first_resolved_date'})
)
df_bugs = pd.merge(df_bugs,min_resolved_date,on=['id'],how='outer')

max_resolved_date = (
    df[(df['id'].isin(resolved_bugs)) & 
      (df['what']=='status') & 
       (df['added']=='RESOLVED')]
    .groupby('id')
    ['when']
    .max()
    .reset_index()
    .rename(index=str,columns={'when':'last_resolved_date'})
)
df_bugs = pd.merge(df_bugs,max_resolved_date,on=['id'],how='outer')

min_fixed_date = (
    df[(df['id'].isin(fixed_bugs)) & 
      (df['what']=='resolution') & 
       (df['added']=='FIXED')]
    .groupby('id')
    ['when']
    .min()
    .reset_index()
    .rename(index=str,columns={'when':'first_fixed_date'})
)
df_bugs = pd.merge(df_bugs,min_fixed_date,on=['id'],how='outer')

max_fixed_date = (
    df[(df['id'].isin(fixed_bugs)) & 
      (df['what']=='resolution') & 
       (df['added']=='FIXED')]
    .groupby('id')
    ['when']
    .max()
    .reset_index()
    .rename(index=str,columns={'when':'last_fixed_date'})
)
df_bugs = pd.merge(df_bugs,max_fixed_date,on=['id'],how='outer')

df_bugs = df_bugs.fillna('')
df_bugs.head()
# Out:
#        id  release   Product       creation_time version resolution  \
# 0  475361      4.5  Platform 2015-08-19 10:50:25     4.5      FIXED
# 1  475365      4.6  Platform 2015-08-19 11:34:37     4.6      FIXED
# 2  475370      4.5  Platform 2015-08-19 12:09:06     4.5  DUPLICATE
# 3  475379      4.5  Platform 2015-08-19 13:39:12     4.5
# 4  475407      4.5  Platform 2015-08-19 17:06:10     4.5      FIXED
#
#    is_assigned  is_resolved  is_fixed first_assignment_date  \
# 0            0            1         1
# 1            0            1         1
# 2            0            0         0
# 3            0            0         0
# 4            0            1         1
#
#   last_assignment_date   first_resolved_date    last_resolved_date  \
# 0                       2015-08-19T11:53:03Z  2015-08-19T11:53:03Z
# 1                       2015-08-26T14:29:30Z  2015-08-26T14:29:30Z
# 2
# 3
# 4                       2015-08-19T17:15:25Z  2015-08-19T17:15:25Z
#
#        first_fixed_date       last_fixed_date
# 0  2015-08-19T11:53:03Z  2015-08-19T11:53:03Z
# 1  2015-08-26T14:29:30Z  2015-08-26T14:29:30Z
# 2
# 3
# 4  2015-08-19T17:15:25Z  2015-08-19T17:15:25Z

# %%
print('Injected assignments for bugs:'+str(len(injected_assignments.id.unique())))
# Out:
# Injected assignments for bugs:6811

# %%
bug_history.to_csv(processed_history_file,index=False)
df_bugs.to_csv(bugs_processing_file,index=False)
