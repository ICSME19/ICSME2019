# %% [markdown]
# # statistics of the eclipse data

# %%
import pandas as pd
import os
import json
import csv
import re, datetime
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, timedelta

from lifelines import KaplanMeierFitter

from global_functions import *

# %%
FIGS_PATH =  'figs'+os.sep+'preliminary'

# %%
relase_creation_ts_all = get_release_dates()

# %%
#Load data
df = pd.read_csv('.'+os.sep+'data'+os.sep+'bugs_info.zip',index_col=False,compression='zip',
                dtype={'release':str,'version':str})
df = df.fillna('')
df['release'] = df.apply(lambda x : str(assign_to_closest_minor(x['version'])), axis=1)
df = trans_to_datetime(df,['creation_time','first_assignment_date','last_assignment_date',
                          'first_resolved_date','last_resolved_date',
                           'first_fixed_date','last_fixed_date'])
df.head(n=2)
# Out:
#        id release   Product       creation_time version resolution  \
# 0  475361     4.5  Platform 2015-08-19 10:50:25     4.5      FIXED
# 1  475365     4.6  Platform 2015-08-19 11:34:37     4.6      FIXED
#
#    is_assigned  is_resolved  is_fixed first_assignment_date  \
# 0            0            1         1                   NaT
# 1            0            1         1                   NaT
#
#                 ...                 last_resolved_date    first_fixed_date  \
# 0               ...                2015-08-19 11:53:03 2015-08-19 11:53:03
# 1               ...                2015-08-26 14:29:30 2015-08-26 14:29:30
#
#       last_fixed_date time_assign_diff time_resolve_diff time_fix_diff  \
# 0 2015-08-19 11:53:03                                  0             0
# 1 2015-08-26 14:29:30                                  0             0
#
#   min_release max_release  min_release_before_version_field  \
# 0         4.5         4.5                             False
# 1         4.6         4.6                             False
#
#    min_release_after_version_field
# 0                            False
# 1                            False
#
# [2 rows x 22 columns]

# %%
all_bugs_per_release = (
    df
    .groupby('release')['id']
    .nunique()
    .reset_index()
    .rename(index=str,columns={'id':'reported'})
)

resolved_bugs_per_release = (
    df[df['is_resolved']==1]
    .groupby('release')['id']
    .nunique()
    .reset_index()
    .rename(index=str,columns={'id':'resolved'})
)
assigned_bugs_per_release = (
    df[df['is_assigned']==1]
    .groupby('release')['id']
    .nunique()
    .reset_index()
    .rename(index=str,columns={'id':'assigned'})
)
stats = pd.merge(all_bugs_per_release,resolved_bugs_per_release,on=['release'],how='outer')
stats = pd.merge(stats,assigned_bugs_per_release,on=['release'],how='outer')
fixed_bugs_per_release = (
    df[df['is_fixed']==1]
    .groupby('release')['id']
    .nunique()
    .reset_index()
    .rename(index=str,columns={'id':'fixed'})
)

stats = pd.merge(stats,fixed_bugs_per_release,on=['release'],how='outer')
stats = sort_df(stats,'release')
stats
# Out:
#    release  reported  resolved  assigned  fixed
# 0      3.0     24937     24088      9963  11995
# 1      3.1     17908     15272      6775   7641
# 2      3.2     15834     14350      6375   7350
# 3      3.3     12642     10853      4871   6442
# 4      3.4     12510     10353      4547   6386
# 5      3.5      9497      7280      3502   4926
# 6      3.6      6810      4347      2349   3370
# 7      3.7      4882      3164      1745   2403
# 8      4.2      7173      4171      2676   3057
# 9      4.3      3734      2303      1546   1634
# 10     4.4      5048      3206      2125   2300
# 11     4.5      5413      3102      1650   2316
# 12     4.6      3964      2157      1316   1766
# 13     4.7      4134      2473      1567   2064
# 14     4.8      2596      1535       940   1328
# 15     4.9       791       420       246    369
# 16    4.10       572       293       187    269

# %%
stats['resolved_perc'] = stats['resolved'] / stats['reported']
stats['fixed_perc'] = stats['fixed'] / stats['resolved']
stats['fixed_perc_reported'] = stats['fixed'] / stats['reported']
stats
# Out:
#    release  reported  resolved  assigned  fixed  resolved_perc  fixed_perc  \
# 0      3.0     24937     24088      9963  11995       0.965954    0.497966
# 1      3.1     17908     15272      6775   7641       0.852803    0.500327
# 2      3.2     15834     14350      6375   7350       0.906278    0.512195
# 3      3.3     12642     10853      4871   6442       0.858488    0.593569
# 4      3.4     12510     10353      4547   6386       0.827578    0.616826
# 5      3.5      9497      7280      3502   4926       0.766558    0.676648
# 6      3.6      6810      4347      2349   3370       0.638326    0.775247
# 7      3.7      4882      3164      1745   2403       0.648095    0.759482
# 8      4.2      7173      4171      2676   3057       0.581486    0.732918
# 9      4.3      3734      2303      1546   1634       0.616765    0.709509
# 10     4.4      5048      3206      2125   2300       0.635103    0.717405
# 11     4.5      5413      3102      1650   2316       0.573065    0.746615
# 12     4.6      3964      2157      1316   1766       0.544147    0.818730
# 13     4.7      4134      2473      1567   2064       0.598210    0.834614
# 14     4.8      2596      1535       940   1328       0.591294    0.865147
# 15     4.9       791       420       246    369       0.530973    0.878571
# 16    4.10       572       293       187    269       0.512238    0.918089
#
#     fixed_perc_reported
# 0              0.481012
# 1              0.426681
# 2              0.464191
# 3              0.509571
# 4              0.510472
# 5              0.518690
# 6              0.494860
# 7              0.492216
# 8              0.426182
# 9              0.437600
# 10             0.455626
# 11             0.427859
# 12             0.445510
# 13             0.499274
# 14             0.511556
# 15             0.466498
# 16             0.470280

# %%
stats2 = stats.copy()
stats2['release'] = stats2['release'].astype(str)

stats2 = sort_df(stats2,'release')

stats2['label'] = ''
for index,row in stats2.iterrows():
    rel = row['release']
    date = relase_creation_ts_all[rel]
    date = date[:date.find(' ')]
    date = date[:date.rfind('-')]
    if rel=='4.2':
        rel='3.8/4.2'
    stats2.loc[index,'label'] = rel+' '+'('+date+')'
    
x = get_x_axis_tick_placement()

stats2 = stats2.set_index('release')

fig, ax = plt.subplots()

fig.set_figheight(9)
fig.set_figwidth(19)

ax.plot(x,stats2[['resolved_perc']],label='ResRate',marker='o')
ax.plot(x,stats2[['fixed_perc']],label='FixRate_resolved',marker='D',linestyle='--')
ax.plot(x,stats2[['fixed_perc_reported']],label='FixRate_reported',marker='*',linestyle='--')

ax.legend(fontsize=18,loc=3)
plt.xlabel('releases', fontsize=18)
plt.ylabel('ratio', fontsize=18)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(18) 
    tick.label.set_horizontalalignment('center')

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(18) 

ax.axvline(x=5.5, c='r',linestyle='--')
ax.axvline(x=11, c='y',linestyle='--')
ax.set_ylim(0,1)

plt.xticks(x, stats2.label.values.tolist())
fig.autofmt_xdate()
plt.show()

ax.get_figure().savefig(FIGS_PATH+os.sep+'preliminary_percentages.pdf', bbox_inches="tight")

# %%
stats[['release','fixed_perc']]
# Out:
#    release  fixed_perc
# 0      3.0    0.497966
# 1      3.1    0.500327
# 2      3.2    0.512195
# 3      3.3    0.593569
# 4      3.4    0.616826
# 5      3.5    0.676648
# 6      3.6    0.775247
# 7      3.7    0.759482
# 8      4.2    0.732918
# 9      4.3    0.709509
# 10     4.4    0.717405
# 11     4.5    0.746615
# 12     4.6    0.818730
# 13     4.7    0.834614
# 14     4.8    0.865147
# 15     4.9    0.878571
# 16    4.10    0.918089

# %%
stats2 = stats.copy()
stats2['release'] = stats2['release'].astype(str)

stats2 = sort_df(stats2,'release')

stats2['label'] = ''
for index,row in stats2.iterrows():
    rel = row['release']
    date = relase_creation_ts_all[rel]
    date = date[:date.find(' ')]
    date = date[:date.rfind('-')]
    if rel=='4.2':
        rel='3.8/4.2'
    stats2.loc[index,'label'] = rel+' '+'('+date+')'
    
x = get_x_axis_tick_placement()

stats2 = stats2.set_index('release')

fig, ax = plt.subplots()

fig.set_figheight(9)
fig.set_figwidth(19)

ax.plot(x,stats2[['reported']],label='reported',marker='o')
ax.plot(x,stats2[['resolved']],label='resolved',marker='D',linestyle='--')
ax.plot(x,stats2[['fixed']],label='fixed',marker='<',linestyle='-.')
ax.plot(x,stats2[['assigned']],label='assigned',marker='*')
ax.legend(fontsize=18,loc=1)
plt.xlabel('releases', fontsize=18)
plt.ylabel('# of bugs', fontsize=18)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(18) 
    tick.label.set_horizontalalignment('center')

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(18) 

ax.axvline(x=7.5, c='g',linestyle='--')
ax.axvline(x=14.3, c='g',linestyle='--')

plt.xticks(x, stats2.label.values.tolist())
fig.autofmt_xdate()
plt.show()

ax.get_figure().savefig(FIGS_PATH+os.sep+'preliminary_stats.pdf', bbox_inches="tight")

# %% [markdown]
# # RESOLUTION STATISTICS

# %%
df_stat = pd.read_csv('.'+os.sep+'data'+os.sep+'bugs_info.zip',index_col=False,compression='zip')
df_stat=df_stat[~df_stat['resolution'].isnull()]

# %%
df_stat.head()
# Out:
#        id  release   Product        creation_time version resolution  \
# 0  475361      4.5  Platform  2015-08-19 10:50:25     4.5      FIXED
# 1  475365      4.6  Platform  2015-08-19 11:34:37     4.6      FIXED
# 2  475370      4.5  Platform  2015-08-19 12:09:06     4.5  DUPLICATE
# 4  475407      4.5  Platform  2015-08-19 17:06:10     4.5      FIXED
# 5  475427      4.5  Platform  2015-08-19 21:37:59     4.5      FIXED
#
#    is_assigned  is_resolved  is_fixed first_assignment_date  \
# 0            0            1         1                   NaN
# 1            0            1         1                   NaN
# 2            0            0         0                   NaN
# 4            0            1         1                   NaN
# 5            0            1         1                   NaN
#
#                 ...                  last_resolved_date     first_fixed_date  \
# 0               ...                 2015-08-19 11:53:03  2015-08-19 11:53:03
# 1               ...                 2015-08-26 14:29:30  2015-08-26 14:29:30
# 2               ...                                 NaN                  NaN
# 4               ...                 2015-08-19 17:15:25  2015-08-19 17:15:25
# 5               ...                 2015-09-28 08:47:16  2015-09-28 08:47:16
#
#        last_fixed_date time_assign_diff time_resolve_diff  time_fix_diff  \
# 0  2015-08-19 11:53:03              NaN               0.0            0.0
# 1  2015-08-26 14:29:30              NaN               0.0            0.0
# 2                  NaN              NaN               NaN            NaN
# 4  2015-08-19 17:15:25              NaN               0.0            0.0
# 5  2015-09-28 08:47:16              NaN               0.0            0.0
#
#    min_release  max_release  min_release_before_version_field  \
# 0          4.5          4.5                             False
# 1          4.6          4.6                             False
# 2          4.5          4.5                             False
# 4          4.5          4.5                             False
# 5          4.5          4.5                             False
#
#    min_release_after_version_field
# 0                            False
# 1                            False
# 2                            False
# 4                            False
# 5                            False
#
# [5 rows x 22 columns]

# %%
dh=df_stat.copy()
len(dh)
# Out:
# 117848

# %%
dh=dh.groupby('resolution')['id'].nunique().reset_index().rename(index=str,columns={'id':'bugs'})
len_resolved = len(df_stat)
dh['proportion']= dh['bugs']/len_resolved
dh=dh[['resolution','proportion']]
dh
# Out:
#     resolution  proportion
# 0    DUPLICATE    0.186359
# 1        FIXED    0.553331
# 2      INVALID    0.073968
# 3        MOVED    0.000076
# 4  NOT_ECLIPSE    0.013959
# 5      WONTFIX    0.071541
# 6   WORKSFORME    0.100765

# %%
dr=df_stat.copy()
dcount=df_stat.copy()

# %%
dr['release'] = dr.apply(lambda x : str(assign_to_closest_minor(x['version'])), axis=1)
dr['release'] = dr['release'].astype(str)

dcount['release'] = dcount.apply(lambda x : str(assign_to_closest_minor(x['version'])), axis=1)

dcount['release'] = dcount['release'].astype(str)

# %%
dcount=dcount.groupby('release')['id'].count().reset_index()
dcount['total']= dcount.apply(lambda x : x['id'], axis=1)
dcount=dcount[['release','total']]
print('total',dcount.total.sum())
dcount
# Out:
# total 117848
#    release  total
# 0      3.0  24101
# 1      3.1  16738
# 2      3.2  14344
# 3      3.3  10944
# 4      3.4  10688
# 5      3.5   7843
# 6      3.6   5339
# 7      3.7   3717
# 8     4.10    341
# 9      4.2   5261
# 10     4.3   2817
# 11     4.4   3869
# 12     4.5   3903
# 13     4.6   2678
# 14     4.7   2923
# 15     4.8   1839
# 16     4.9    503

# %%
dr=dr.groupby(['release','resolution']).count()[['id']].reset_index()
dr=dr.rename(columns={'id':'count'})
dr.head()
# Out:
#   release   resolution  count
# 0     3.0    DUPLICATE   5188
# 1     3.0        FIXED  11805
# 2     3.0      INVALID   2139
# 3     3.0  NOT_ECLIPSE     14
# 4     3.0      WONTFIX   2080

# %%
stat_resolution_release = pd.merge(dr,dcount,on=['release'],how='outer')
stat_resolution_release
# Out:
#     release   resolution  count  total
# 0       3.0    DUPLICATE   5188  24101
# 1       3.0        FIXED  11805  24101
# 2       3.0      INVALID   2139  24101
# 3       3.0  NOT_ECLIPSE     14  24101
# 4       3.0      WONTFIX   2080  24101
# 5       3.0   WORKSFORME   2875  24101
# 6       3.1    DUPLICATE   3215  16738
# 7       3.1        FIXED   8311  16738
# 8       3.1      INVALID   1587  16738
# 9       3.1  NOT_ECLIPSE     14  16738
# 10      3.1      WONTFIX   1651  16738
# 11      3.1   WORKSFORME   1960  16738
# 12      3.2    DUPLICATE   2840  14344
# 13      3.2        FIXED   7215  14344
# 14      3.2      INVALID   1204  14344
# 15      3.2  NOT_ECLIPSE     56  14344
# 16      3.2      WONTFIX   1425  14344
# 17      3.2   WORKSFORME   1604  14344
# 18      3.3    DUPLICATE   1948  10944
# 19      3.3        FIXED   6347  10944
# 20      3.3      INVALID    680  10944
# 21      3.3  NOT_ECLIPSE    125  10944
# 22      3.3      WONTFIX    829  10944
# 23      3.3   WORKSFORME   1015  10944
# 24      3.4    DUPLICATE   1902  10688
# 25      3.4        FIXED   6298  10688
# 26      3.4      INVALID    655  10688
# 27      3.4  NOT_ECLIPSE    197  10688
# 28      3.4      WONTFIX    678  10688
# 29      3.4   WORKSFORME    958  10688
# ..      ...          ...    ...    ...
# 77      4.5  NOT_ECLIPSE    121   3903
# 78      4.5      WONTFIX    164   3903
# 79      4.5   WORKSFORME    345   3903
# 80      4.6    DUPLICATE    418   2678
# 81      4.6        FIXED   1727   2678
# 82      4.6      INVALID    147   2678
# 83      4.6        MOVED      1   2678
# 84      4.6  NOT_ECLIPSE     93   2678
# 85      4.6      WONTFIX     91   2678
# 86      4.6   WORKSFORME    201   2678
# 87      4.7    DUPLICATE    357   2923
# 88      4.7        FIXED   2031   2923
# 89      4.7      INVALID    145   2923
# 90      4.7        MOVED      1   2923
# 91      4.7  NOT_ECLIPSE     77   2923
# 92      4.7      WONTFIX     98   2923
# 93      4.7   WORKSFORME    214   2923
# 94      4.8    DUPLICATE    204   1839
# 95      4.8        FIXED   1301   1839
# 96      4.8      INVALID    107   1839
# 97      4.8  NOT_ECLIPSE     44   1839
# 98      4.8      WONTFIX     63   1839
# 99      4.8   WORKSFORME    120   1839
# 100     4.9    DUPLICATE     53    503
# 101     4.9        FIXED    363    503
# 102     4.9      INVALID     28    503
# 103     4.9        MOVED      1    503
# 104     4.9  NOT_ECLIPSE     14    503
# 105     4.9      WONTFIX     11    503
# 106     4.9   WORKSFORME     33    503
#
# [107 rows x 4 columns]

# %%
stat_resolution_release['percentage']= stat_resolution_release.apply(lambda x : x['count']*100/x['total'], axis=1)

# %%
stat_resolution_release=stat_resolution_release[['release','resolution','percentage']]
stat_resolution_release
# Out:
#     release   resolution  percentage
# 0       3.0    DUPLICATE   21.526078
# 1       3.0        FIXED   48.981370
# 2       3.0      INVALID    8.875150
# 3       3.0  NOT_ECLIPSE    0.058089
# 4       3.0      WONTFIX    8.630347
# 5       3.0   WORKSFORME   11.928966
# 6       3.1    DUPLICATE   19.207791
# 7       3.1        FIXED   49.653483
# 8       3.1      INVALID    9.481420
# 9       3.1  NOT_ECLIPSE    0.083642
# 10      3.1      WONTFIX    9.863783
# 11      3.1   WORKSFORME   11.709882
# 12      3.2    DUPLICATE   19.799219
# 13      3.2        FIXED   50.299777
# 14      3.2      INVALID    8.393753
# 15      3.2  NOT_ECLIPSE    0.390407
# 16      3.2      WONTFIX    9.934467
# 17      3.2   WORKSFORME   11.182376
# 18      3.3    DUPLICATE   17.799708
# 19      3.3        FIXED   57.995249
# 20      3.3      INVALID    6.213450
# 21      3.3  NOT_ECLIPSE    1.142178
# 22      3.3      WONTFIX    7.574927
# 23      3.3   WORKSFORME    9.274488
# 24      3.4    DUPLICATE   17.795659
# 25      3.4        FIXED   58.925898
# 26      3.4      INVALID    6.128368
# 27      3.4  NOT_ECLIPSE    1.843189
# 28      3.4      WONTFIX    6.343563
# 29      3.4   WORKSFORME    8.963323
# ..      ...          ...         ...
# 77      4.5  NOT_ECLIPSE    3.100179
# 78      4.5      WONTFIX    4.201896
# 79      4.5   WORKSFORME    8.839354
# 80      4.6    DUPLICATE   15.608663
# 81      4.6        FIXED   64.488424
# 82      4.6      INVALID    5.489171
# 83      4.6        MOVED    0.037341
# 84      4.6  NOT_ECLIPSE    3.472741
# 85      4.6      WONTFIX    3.398058
# 86      4.6   WORKSFORME    7.505601
# 87      4.7    DUPLICATE   12.213479
# 88      4.7        FIXED   69.483407
# 89      4.7      INVALID    4.960657
# 90      4.7        MOVED    0.034211
# 91      4.7  NOT_ECLIPSE    2.634280
# 92      4.7      WONTFIX    3.352720
# 93      4.7   WORKSFORME    7.321245
# 94      4.8    DUPLICATE   11.092985
# 95      4.8        FIXED   70.744970
# 96      4.8      INVALID    5.818380
# 97      4.8  NOT_ECLIPSE    2.392605
# 98      4.8      WONTFIX    3.425775
# 99      4.8   WORKSFORME    6.525285
# 100     4.9    DUPLICATE   10.536779
# 101     4.9        FIXED   72.166998
# 102     4.9      INVALID    5.566600
# 103     4.9        MOVED    0.198807
# 104     4.9  NOT_ECLIPSE    2.783300
# 105     4.9      WONTFIX    2.186879
# 106     4.9   WORKSFORME    6.560636
#
# [107 rows x 3 columns]

# %% [markdown]
# # general stats

# %%
def get_bug_statistics_per_release(df_w,only_one_year):
    #Calculate general stastics per release
    df_ret=pd.DataFrame()
    df_w['release'] = df_w['release'].astype(str)   
        
    for version in df_w.release.unique():
        start_date = relase_creation_ts_all[version]
        start_date = pd.to_datetime(start_date)
        end_date_before=addYears(start_date,-1)
        end_date_after=addYears(start_date,1)
        #Fetch the bugs of this version
        version_bugs = df_w[df_w['release']==version]
        version_bugs = trans_to_datetime(version_bugs,
                                        ['creation_time'])
        total=len(version_bugs.id.unique())
        if only_one_year:

            #the bug before release 
            bugs_before_release = version_bugs[(version_bugs['creation_time']<start_date) & (version_bugs['creation_time']>=end_date_before) ]

            #the bug after release 
            bugs_after_release = version_bugs[(version_bugs['creation_time']>= start_date) & (version_bugs['creation_time']< end_date_after)]
            
        
        else:
            #the bug before release 
            bugs_before_release = version_bugs[version_bugs['creation_time']<start_date]

            #the bug after release 
            bugs_after_release = version_bugs[version_bugs['creation_time']>= start_date]



        
        before_release = len(bugs_before_release.id.unique())
   

        after_release = len(bugs_after_release.id.unique())
        if only_one_year:
            total=before_release+after_release
 

        df_ret=df_ret.append({"release": version , 
                           "total": total ,
                           'before_release': before_release, 
                           'after_release':after_release, 
                        },
                         ignore_index=True)
    return df_ret

# %%
post_pre_df = pd.read_csv('.'+os.sep+'data'+os.sep+'bugs_info.zip',index_col=False,compression='zip')
post_pre_df = post_pre_df.fillna('')
post_pre_df['release'] = post_pre_df.apply(lambda x : str(assign_to_closest_minor(x['version'])), axis=1)
post_pre_df['release'] = post_pre_df['release'].astype(str)
post_pre_df['release'] = post_pre_df['release'].apply(lambda x: '4.2' if x == '3.8' else x )

# %%
post_pre_df.release.unique()
# Out:
# array(['4.5', '4.6', '4.4', '3.7', '4.2', '4.3', '3.6', '4.8', '3.1',
#        '4.7', '4.10', '3.4', '3.5', '3.3', '3.2', '3.0', '4.9'],
#       dtype=object)

# %%
post_pre_df_year=get_bug_statistics_per_release(post_pre_df,True)
post_pre_df=get_bug_statistics_per_release(post_pre_df,False)
post_pre_df = sort_df(post_pre_df,'release')

# %%
post_pre_df
# Out:
#    release  after_release  before_release    total
# 0      3.0         6970.0         17967.0  24937.0
# 1      3.1         5718.0         12190.0  17908.0
# 2      3.2         5354.0         10480.0  15834.0
# 3      3.3         4550.0          8092.0  12642.0
# 4      3.4         4579.0          7931.0  12510.0
# 5      3.5         2699.0          6798.0   9497.0
# 6      3.6         2292.0          4518.0   6810.0
# 7      3.7         1957.0          2925.0   4882.0
# 8      4.2         3708.0          3465.0   7173.0
# 9      4.3         1824.0          1910.0   3734.0
# 10     4.4         2173.0          2875.0   5048.0
# 11     4.5         2707.0          2706.0   5413.0
# 12     4.6         1894.0          2070.0   3964.0
# 13     4.7         1774.0          2360.0   4134.0
# 14     4.8          495.0          2101.0   2596.0
# 15     4.9          393.0           398.0    791.0
# 16    4.10          179.0           393.0    572.0

# %%
stats2 = post_pre_df.copy()
stats2 = stats2[['release','before_release','after_release']]

stats2 = sort_df(stats2,'release')
x = get_x_axis_tick_placement()

stats2['label'] = ''

for index,row in stats2.iterrows():
    rel = row['release']
    date = relase_creation_ts_all[rel]
    date = date[:date.find(' ')]
    date = date[:date.rfind('-')]
    if rel=='4.2':
        rel='3.8/4.2'
    stats2.loc[index,'label'] = rel#+'\n'+'('+date+')'

stats2 = stats2.set_index('release')

fig, ax = plt.subplots()

fig.set_figheight(9)
fig.set_figwidth(19)

ax.plot(x,stats2[['after_release']],label='after_release',marker='o')
ax.plot(x,stats2[['before_release']],label='before_release',marker='D',linestyle='--')


ax.legend(fontsize=18,loc=1)
plt.xlabel('releases', fontsize=18)
plt.ylabel('# of bugs', fontsize=18)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(17) 
    tick.label.set_horizontalalignment('center')

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(17) 

ax.axvline(x=7.5, c='g',linestyle='--')
ax.axvline(x=14.3, c='g',linestyle='--')


plt.xticks(x, stats2.label.values.tolist())
fig.autofmt_xdate()
plt.show()

ax.get_figure().savefig(FIGS_PATH+os.sep+'preliminary_stats_before&after.pdf', bbox_inches="tight")

# %% [markdown]
# # STAT ON RATIO OF REPORTED BUGS OF BEFORE AND AFTER A RELEASE

# %%
ratio_stat=post_pre_df.copy()
ratio_stat.head()
# Out:
#   release  after_release  before_release    total
# 0     3.0         6970.0         17967.0  24937.0
# 1     3.1         5718.0         12190.0  17908.0
# 2     3.2         5354.0         10480.0  15834.0
# 3     3.3         4550.0          8092.0  12642.0
# 4     3.4         4579.0          7931.0  12510.0

# %%
ratio_stat['ratio']=ratio_stat['after_release']/ratio_stat['before_release']
ratio_stat=sort_df(ratio_stat,'release')
ratio_stat
# Out:
#    release  after_release  before_release    total     ratio
# 0      3.0         6970.0         17967.0  24937.0  0.387933
# 1      3.1         5718.0         12190.0  17908.0  0.469073
# 2      3.2         5354.0         10480.0  15834.0  0.510878
# 3      3.3         4550.0          8092.0  12642.0  0.562284
# 4      3.4         4579.0          7931.0  12510.0  0.577355
# 5      3.5         2699.0          6798.0   9497.0  0.397029
# 6      3.6         2292.0          4518.0   6810.0  0.507304
# 7      3.7         1957.0          2925.0   4882.0  0.669060
# 8      4.2         3708.0          3465.0   7173.0  1.070130
# 9      4.3         1824.0          1910.0   3734.0  0.954974
# 10     4.4         2173.0          2875.0   5048.0  0.755826
# 11     4.5         2707.0          2706.0   5413.0  1.000370
# 12     4.6         1894.0          2070.0   3964.0  0.914976
# 13     4.7         1774.0          2360.0   4134.0  0.751695
# 14     4.8          495.0          2101.0   2596.0  0.235602
# 15     4.9          393.0           398.0    791.0  0.987437
# 16    4.10          179.0           393.0    572.0  0.455471

# %%
fig, ax = plt.subplots()

fig.set_figheight(13)
fig.set_figwidth(24)

ax.plot(ratio_stat['release'],ratio_stat['ratio'],label='ratio_after_before',marker='o')
plt.xlabel('releases', fontsize=16)
plt.ylabel('ratio post-/pre- bugs', fontsize=16)


for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(16) 
    tick.label.set_horizontalalignment('center')

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(16) 

fig.autofmt_xdate()

plt.show()
ax.get_figure().savefig(FIGS_PATH+os.sep+'ratio_after_before.pdf', bbox_inches="tight")

# %%
ratio_stat[['release','ratio']]
# Out:
#    release     ratio
# 0      3.0  0.387933
# 1      3.1  0.469073
# 2      3.2  0.510878
# 3      3.3  0.562284
# 4      3.4  0.577355
# 5      3.5  0.397029
# 6      3.6  0.507304
# 7      3.7  0.669060
# 8      4.2  1.070130
# 9      4.3  0.954974
# 10     4.4  0.755826
# 11     4.5  1.000370
# 12     4.6  0.914976
# 13     4.7  0.751695
# 14     4.8  0.235602
# 15     4.9  0.987437
# 16    4.10  0.455471

# %% [markdown]
# # STAT ON RATIO OF REPORTED/ASSIGNED BUGS OF BEFORE AND AFTER A RELEASE

# %%
stats_FR=stats.copy()

# %%
stats_FR['ratio_resolved']=stats_FR['resolved']/stats_FR['reported']
stats_FR['ratio_fixed']=stats_FR['fixed']/stats_FR['resolved']
stats_FR=sort_df(stats_FR,'release')
latex_FR=stats_FR[['release','ratio_resolved','ratio_fixed']]

# %%
stats_FR.head()
# Out:
#   release  reported  resolved  assigned  fixed  resolved_perc  fixed_perc  \
# 0     3.0     24937     24088      9963  11995       0.965954    0.497966
# 1     3.1     17908     15272      6775   7641       0.852803    0.500327
# 2     3.2     15834     14350      6375   7350       0.906278    0.512195
# 3     3.3     12642     10853      4871   6442       0.858488    0.593569
# 4     3.4     12510     10353      4547   6386       0.827578    0.616826
#
#    fixed_perc_reported  ratio_resolved  ratio_fixed
# 0             0.481012        0.965954     0.497966
# 1             0.426681        0.852803     0.500327
# 2             0.464191        0.906278     0.512195
# 3             0.509571        0.858488     0.593569
# 4             0.510472        0.827578     0.616826

# %%
print(latex_FR.to_latex(index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
# release &  ratio\_resolved &  ratio\_fixed \\
# \midrule
#     3.0 &        0.965954 &     0.497966 \\
#     3.1 &        0.852803 &     0.500327 \\
#     3.2 &        0.906278 &     0.512195 \\
#     3.3 &        0.858488 &     0.593569 \\
#     3.4 &        0.827578 &     0.616826 \\
#     3.5 &        0.766558 &     0.676648 \\
#     3.6 &        0.638326 &     0.775247 \\
#     3.7 &        0.648095 &     0.759482 \\
#     4.2 &        0.581486 &     0.732918 \\
#     4.3 &        0.616765 &     0.709509 \\
#     4.4 &        0.635103 &     0.717405 \\
#     4.5 &        0.573065 &     0.746615 \\
#     4.6 &        0.544147 &     0.818730 \\
#     4.7 &        0.598210 &     0.834614 \\
#     4.8 &        0.591294 &     0.865147 \\
#     4.9 &        0.530973 &     0.878571 \\
#    4.10 &        0.512238 &     0.918089 \\
# \bottomrule
# \end{tabular}

# %%
df_hist = pd.read_csv('.'+os.sep+'data'+os.sep+'bug_history.zip',compression='zip',index_col=False,
                dtype={'release':str,'version':str})
df_hist
# Out:
#                                                      added      id  \
# 0                          platform-help-inbox@eclipse.org  100001
# 1                                                     Help  100001
# 2                                                 Platform  100001
# 3                                       konradk@ca.ibm.com  100001
# 4                                         dejan@ca.ibm.com  100001
# 5                                                  3.1 RC3  100001
# 6                                                       P2  100001
# 7                                                 RESOLVED  100001
# 8                                                    FIXED  100001
# 9                                   david_audel@fr.ibm.com  100002
# 10                                                RESOLVED  100004
# 11                                               DUPLICATE  100004
# 12       ClassCastException using array object as gener...  100007
# 13                               philippe_mulet@fr.ibm.com  100007
# 14                                                 3.1 RC3  100007
# 15                                daniel_megert@ch.ibm.com  100007
# 16       [1.5][compiler] ClassCastException using array...  100007
# 17                                                RESOLVED  100007
# 18                                                   FIXED  100007
# 19                                                VERIFIED  100007
# 20                                   tom_eicher@ch.ibm.com  100009
# 21       [content assist] Content assist uses generic p...  100009
# 22                              jdt-core-inbox@eclipse.org  100009
# 23                                                    Core  100009
# 24       [assist] Content assist uses generic parameter...  100009
# 25                                daniel_megert@ch.ibm.com  100009
# 26                                  david_audel@fr.ibm.com  100009
# 27                                 dirk_baeumer@ch.ibm.com  100009
# 28                                                   3.1.1  100009
# 29                                                 3.1 RC4  100009
# ...                                                    ...     ...
# 1102872                                           ASSIGNED   89401
# 1102873                                           ASSIGNED   89839
# 1102874                                           ASSIGNED   89874
# 1102875                                           ASSIGNED   89974
# 1102876                                           ASSIGNED   89980
# 1102877                                           ASSIGNED   90361
# 1102878                                           ASSIGNED   90731
# 1102879                                           ASSIGNED   90822
# 1102880                                           ASSIGNED   90898
# 1102881                                           ASSIGNED   91120
# 1102882                                           ASSIGNED   91607
# 1102883                                           ASSIGNED   92238
# 1102884                                           ASSIGNED   92471
# 1102885                                           ASSIGNED   92596
# 1102886                                           ASSIGNED   92639
# 1102887                                           ASSIGNED   92894
# 1102888                                           ASSIGNED   92896
# 1102889                                           ASSIGNED   93652
# 1102890                                           ASSIGNED   94231
# 1102891                                           ASSIGNED   94415
# 1102892                                           ASSIGNED   94647
# 1102893                                           ASSIGNED   94796
# 1102894                                           ASSIGNED   95105
# 1102895                                           ASSIGNED   95171
# 1102896                                           ASSIGNED   95358
# 1102897                                           ASSIGNED   96499
# 1102898                                           ASSIGNED   96674
# 1102899                                           ASSIGNED   96836
# 1102900                                           ASSIGNED   97002
# 1102901                                           ASSIGNED   97050
#
#                                                    removed              what  \
# 0                                 pde-ui-inbox@eclipse.org       assigned_to
# 1                                                       UI         component
# 2                                                      PDE           product
# 3                                                      NaN                cc
# 4                          platform-help-inbox@eclipse.org       assigned_to
# 5                                                      ---  target_milestone
# 6                                                       P3          priority
# 7                                                      NEW            status
# 8                                                      NaN        resolution
# 9                               jdt-core-inbox@eclipse.org       assigned_to
# 10                                                     NEW            status
# 11                                                     NaN        resolution
# 12       Internal compiler error using array object as ...           summary
# 13                              jdt-core-inbox@eclipse.org       assigned_to
# 14                                                     ---  target_milestone
# 15                                                     NaN                cc
# 16       ClassCastException using array object as gener...           summary
# 17                                                     NEW            status
# 18                                                     NaN        resolution
# 19                                                RESOLVED            status
# 20                                                     NaN                cc
# 21       Content assist uses generic parameter name arg...           summary
# 22                              jdt-text-inbox@eclipse.org       assigned_to
# 23                                                    Text         component
# 24       [content assist] Content assist uses generic p...           summary
# 25                                                     NaN                cc
# 26                              jdt-core-inbox@eclipse.org       assigned_to
# 27                                                     NaN                cc
# 28                                                     ---  target_milestone
# 29                                                   3.1.1  target_milestone
# ...                                                    ...               ...
# 1102872                                                NaN            status
# 1102873                                                NaN            status
# 1102874                                                NaN            status
# 1102875                                                NaN            status
# 1102876                                                NaN            status
# 1102877                                                NaN            status
# 1102878                                                NaN            status
# 1102879                                                NaN            status
# 1102880                                                NaN            status
# 1102881                                                NaN            status
# 1102882                                                NaN            status
# 1102883                                                NaN            status
# 1102884                                                NaN            status
# 1102885                                                NaN            status
# 1102886                                                NaN            status
# 1102887                                                NaN            status
# 1102888                                                NaN            status
# 1102889                                                NaN            status
# 1102890                                                NaN            status
# 1102891                                                NaN            status
# 1102892                                                NaN            status
# 1102893                                                NaN            status
# 1102894                                                NaN            status
# 1102895                                                NaN            status
# 1102896                                                NaN            status
# 1102897                                                NaN            status
# 1102898                                                NaN            status
# 1102899                                                NaN            status
# 1102900                                                NaN            status
# 1102901                                                NaN            status
#
#                          when                              who
# 0        2005-06-14T16:16:00Z          wassim.melhem@gmail.com
# 1        2005-06-14T16:16:00Z          wassim.melhem@gmail.com
# 2        2005-06-14T16:16:00Z          wassim.melhem@gmail.com
# 3        2005-06-14T17:17:31Z               konradk@ca.ibm.com
# 4        2005-06-14T17:17:31Z               konradk@ca.ibm.com
# 5        2005-06-14T20:26:08Z               konradk@ca.ibm.com
# 6        2005-06-14T20:44:53Z                 dejan@ca.ibm.com
# 7        2005-06-14T21:26:05Z                 dejan@ca.ibm.com
# 8        2005-06-14T21:26:05Z                 dejan@ca.ibm.com
# 9        2006-10-06T19:42:16Z       Olivier_Thomann@ca.ibm.com
# 10       2005-06-14T16:32:08Z          dirk_baeumer@ch.ibm.com
# 11       2005-06-14T16:32:08Z          dirk_baeumer@ch.ibm.com
# 12       2005-06-14T18:31:55Z       Olivier_Thomann@ca.ibm.com
# 13       2005-06-14T23:05:59Z        philippe_mulet@fr.ibm.com
# 14       2005-06-14T23:05:59Z        philippe_mulet@fr.ibm.com
# 15       2005-06-15T08:47:35Z        philippe_mulet@fr.ibm.com
# 16       2005-06-15T08:48:39Z        philippe_mulet@fr.ibm.com
# 17       2005-06-15T09:33:28Z        philippe_mulet@fr.ibm.com
# 18       2005-06-15T09:33:28Z        philippe_mulet@fr.ibm.com
# 19       2005-06-16T18:26:01Z       Olivier_Thomann@ca.ibm.com
# 20       2005-06-14T22:02:15Z         daniel_megert@ch.ibm.com
# 21       2005-06-14T22:02:38Z         daniel_megert@ch.ibm.com
# 22       2005-06-15T06:40:08Z         eclipse@tom.hofmann.name
# 23       2005-06-15T06:40:08Z         eclipse@tom.hofmann.name
# 24       2005-06-15T06:40:08Z         eclipse@tom.hofmann.name
# 25       2005-06-15T07:38:37Z         daniel_megert@ch.ibm.com
# 26       2005-06-15T11:39:18Z           david_audel@fr.ibm.com
# 27       2005-06-21T11:08:14Z       jerome_lanneluc@fr.ibm.com
# 28       2005-06-21T13:01:25Z        philippe_mulet@fr.ibm.com
# 29       2005-06-21T13:33:48Z        philippe_mulet@fr.ibm.com
# ...                       ...                              ...
# 1102872  2009-09-25T20:40:58Z          swt-triaged@eclipse.org
# 1102873  2009-07-09T23:07:04Z  platform-ui-triaged@eclipse.org
# 1102874  2009-03-06T22:09:44Z  platform-ui-triaged@eclipse.org
# 1102875  2009-08-13T13:28:36Z          swt-triaged@eclipse.org
# 1102876  2009-11-19T12:06:08Z  platform-ui-triaged@eclipse.org
# 1102877  2009-07-15T16:16:21Z  platform-ui-triaged@eclipse.org
# 1102878  2012-06-21T19:54:47Z          swt-triaged@eclipse.org
# 1102879  2009-07-09T23:07:14Z  platform-ui-triaged@eclipse.org
# 1102880  2009-07-10T00:08:05Z  platform-ui-triaged@eclipse.org
# 1102881  2009-07-15T16:06:33Z  platform-ui-triaged@eclipse.org
# 1102882  2009-08-19T12:48:23Z          swt-triaged@eclipse.org
# 1102883  2009-11-26T14:53:15Z  platform-ui-triaged@eclipse.org
# 1102884  2009-08-26T16:58:20Z          swt-triaged@eclipse.org
# 1102885  2009-07-15T16:16:23Z  platform-ui-triaged@eclipse.org
# 1102886  2009-09-25T20:40:50Z          swt-triaged@eclipse.org
# 1102887  2009-11-11T22:31:48Z  platform-ui-triaged@eclipse.org
# 1102888  2009-08-13T13:29:26Z          swt-triaged@eclipse.org
# 1102889  2009-08-13T15:27:17Z          swt-triaged@eclipse.org
# 1102890  2009-11-26T14:55:10Z  platform-ui-triaged@eclipse.org
# 1102891  2009-09-25T20:40:55Z          swt-triaged@eclipse.org
# 1102892  2009-07-15T16:16:25Z  platform-ui-triaged@eclipse.org
# 1102893  2009-07-09T23:07:19Z  platform-ui-triaged@eclipse.org
# 1102894  2010-01-27T15:28:20Z          swt-triaged@eclipse.org
# 1102895  2009-07-09T23:07:21Z  platform-ui-triaged@eclipse.org
# 1102896  2009-07-09T23:07:22Z  platform-ui-triaged@eclipse.org
# 1102897  2009-08-28T19:12:49Z          swt-triaged@eclipse.org
# 1102898  2009-08-19T16:19:00Z          swt-triaged@eclipse.org
# 1102899  2009-07-09T23:27:15Z  platform-ui-triaged@eclipse.org
# 1102900  2009-08-28T19:12:52Z          swt-triaged@eclipse.org
# 1102901  2009-08-19T16:21:03Z          swt-triaged@eclipse.org
#
# [1102902 rows x 6 columns]

# %%
df_hist[(df_hist['what']=='resolution')].added.unique()
# Out:
# array(['FIXED', 'DUPLICATE', 'WONTFIX', 'INVALID', 'WORKSFORME', nan,
#        'LATER', 'REMIND', 'NOT_ECLIPSE', 'MOVED'], dtype=object)

# %%
later = df_hist[(df_hist['what']=='resolution') & (df_hist['added']=='LATER')]
later = pd.merge(later,df[['id','version','release']],on=['id'],how='left')
later.groupby('release')['id'].nunique().reset_index()
# Out:
#   release   id
# 0     3.0  929
# 1     3.1  473
# 2     3.2  254
# 3     3.3   33
# 4     3.5    1

# %%
remind = df_hist[(df_hist['what']=='resolution') & (df_hist['added']=='REMIND')]
remind = pd.merge(remind,df[['id','version','release']],on=['id'],how='left')
remind.groupby('release')['id'].nunique().reset_index()
# Out:
#   release   id
# 0     3.0  642
# 1     3.1  631
# 2     3.2  460
# 3     3.3   78
